# %% [markdown]
# # Reproduce McRae et al. 2024 Table 3
#
# This v0.1 notebook is a placeholder for the future published Table 3 reproduction workflow. No scientific equations are implemented in this scaffold PR.

# %%
from thalmetis_edr import mcrae_2024_table3_inputs

mcrae_2024_table3_inputs()
